# %%
# %run setup.ipynb
# Out:
# <style type="text/css">
# .container {
#     width: 100%;
# }
# </style>

# %%
df_xpclr = phase1_selection.xpclr_windowed
df_xpclr.head()
# Out:
#                     AOMvsGWA  BFMvsAOM  BFMvsGWA  BFSvsBFM  BFSvsGWA  \
# chrom start stop
# 2L    1     20000        NaN       NaN       NaN       NaN       NaN
#       20001 40000        NaN       NaN       NaN       NaN       NaN
#       40001 60000  -0.540672 -0.356354 -0.324068  0.363424  1.090233
#       60001 80000        NaN       NaN       NaN  0.028466       NaN
#       80001 100000       NaN       NaN       NaN       NaN       NaN
#
#                     BFSvsUGS  CMS_savannavsBFS  CMS_savannavsGAS  \
# chrom start stop
# 2L    1     20000        NaN               NaN               NaN
#       20001 40000        NaN               NaN               NaN
#       40001 60000        NaN               NaN               NaN
#       60001 80000        NaN               NaN               NaN
#       80001 100000       NaN               NaN               NaN
#
#                     CMS_savannavsGWA  CMS_savannavsUGS  GASvsAOM  GASvsBFS  \
# chrom start stop
# ...

# %%
df_h12 = phase1_selection.hstats_windowed
df_h12.head()
# Out:
#                     AOM  BFM  BFS  CMS  GAS  GNS  GWA  UGS
# chrom start stop
# 2L    1     20000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#       20001 40000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#       40001 60000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#       60001 80000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#       80001 100000  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
chrom = '2R', '2L'
fig, axs = plt.subplots(nrows=2, figsize=(16, 8))

ax = axs[0]
rockies.plot_signal(df_xpclr, col='BFSvsGWA', chrom=chrom, recmap=recmap,
                    distance='genetic', ax=ax)
ax.set_ylabel('XPCLR')
ax.set_ylim(0, 20)

ax = axs[1]
rockies.plot_signal(df_h12, col='BFS', chrom=chrom, recmap=recmap,
                    distance='genetic', ax=ax)
ax.set_ylabel('H12');

# %%
chrom = '2R'
fig, axs = plt.subplots(nrows=2, figsize=(16, 8))

ax = axs[0]
rockies.plot_signal(df_xpclr, col='BFSvsGWA', chrom=chrom, recmap=recmap,
                    distance='genetic', ax=ax)
ax.set_ylabel('XPCLR')
ax.set_ylim(0, 20)

ax = axs[1]
rockies.plot_signal(df_h12, col='BFS', chrom=chrom, recmap=recmap,
                    distance='genetic', ax=ax)
ax.set_ylabel('H12');

# %%
chrom = ('3R', '3L')
fig, axs = plt.subplots(nrows=2, figsize=(16, 8))

ax = axs[0]
rockies.plot_signal(df_xpclr, col='BFSvsGWA', chrom=chrom, recmap=recmap,
                    distance='genetic', ax=ax)
ax.set_ylabel('XPCLR')
ax.set_ylim(0, 10)

ax = axs[1]
rockies.plot_signal(df_h12, col='BFS', chrom=chrom, recmap=recmap,
                    distance='genetic', ax=ax)
ax.set_ylabel('H12');
